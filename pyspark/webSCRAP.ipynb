# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
html = """
<p class='my-class'>Hello, world!</p>
<ul>
    <li>Item 1</li>
    <li>Item 2</li>
    <li>Item 3</li>
</ul>
"""

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}

# %%
# r = requests.get(html,verify=False)
print(r)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # r = requests.get(html,verify=False)
# ----> 2 print(r)
#
# NameError: name 'r' is not defined

# %%
soup = BeautifulSoup(html, 'html.parser')

# %%
print(soup)
# Out:
# <p class="my-class">Hello, world!</p>
# <ul>
# <li>Item 1</li>
# <li>Item 2</li>
# <li>Item 3</li>
# </ul>

# %%
items = soup.find('ul')
print(len(items))
# Out:
# 7

# %%
print(items)
# Out:
# <ul>
# <li>Item 1</li>
# <li>Item 2</li>
# <li>Item 3</li>
# </ul>

# %%
titleL=[]
companyL=[]
for  c in j_c:
    titleL.append(c.find('h2',class_='title is-5').text)
    companyL.append(c.find('h3',class_='subtitle is-6 company').text)

# %%
import pandas as pd

# %%
print(len(titleL))

# %%
data = {'title':titleL,'company':companyL}
df=pd.DataFrame(data)
print(df)

# %%
selector = "div.col-sm-6.product_main > h1"

element = soup.select_one(selector)

element_text=element.text

if element:
    print("Element Text:", element_text)
else:
    print("Element not found on the page.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 5
#       1 selector = "div.col-sm-6.product_main > h1"
#       3 element = soup.select_one(selector)
# ----> 5 element_text=element.text
#       7 if element:
#       8     print("Element Text:", element_text)
#
# AttributeError: 'NoneType' object has no attribute 'text'
